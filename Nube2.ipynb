# %% [markdown]
# <a href="https://colab.research.google.com/github/maxluna12/C1006/blob/main/Nube2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Ejemplo:
Generación de una nube de palabras utilizando argumentos predeterminados.
"""

import os

from os import path
from wordcloud import WordCloud

# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

# Read the whole text.
text = open(path.join(d, '/content/drive/MyDrive/Colab Notebooks/scraping_notas_pagina12.csv')).read()

# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# The pil way (if

# %%
import pandas as np
import re

# %%
stop_words = [
  
]
symbols = [
    '¿','?','~','`','!','¡','@','#','$','%','^',
    '*','(',')','_','-','+','=','{','}','[',
    ']','\\',':',';','<','>','/', '.', ',','&','\n'
    ,'\r','\t', '|', '“', '"', '–', '”', '©', '-', '—',
    '…', ';', '‘','’'
]

def split_text(text) -> list:
    return re.findall(r'\S+', text)

def remove_stop_words_from_text(text) -> list:
    res = []
    subwords = split_text(text)
    for item in subwords:
        if not item in stop_words:
            res.append(item)
    return res

def remove_symbols (text) -> str:
    res = text
    for char in symbols:
        res = res.replace(char, '')
    return res

def clean_text (text) -> list:
    res = text.lower()
    res = remove_symbols(res)
    res = remove_stop_words_from_text(res)
    return res
text = open(path.join(d, '/content/drive/MyDrive/Colab Notebooks/scraping_notas_pagina12.csv')).read()

text = clean_text(text)
print(text)
# Out:
# ['fechavolantatitulocopetecuerpoautorurl06', 'de', 'noviembre', 'de', '2022', '0029en', 'egipto', '30', 'mil', 'personas', 'entre', 'autoridades', 'gubernamentales', 'y', 'expertos', 'participarán', 'del', 'encuentrouna', 'nueva', 'edición', 'de', 'la', 'cumbre', 'climática', 'entre', 'el', 'escepticismo', 'y', 'la', 'esperanza', 'los', 'debates', 'en', 'torno', 'al', 'recambio', 'de', 'la', 'matriz', 'energética', 'el', 'impacto', 'dela', 'geopolítica', 'en', 'las', 'posibilidades', 'de', 'cambio', 'reales', 'los', 'antecedentes', 'y', 'las', 'proyeccionesoscuras', 'signadas', 'por', 'un', 'financiamiento', 'que', 'se', 'promete', 'pero', 'nunca', 'llega', 'paralas', 'sociedades', 'más', 'vulnerables', 'por', 'pablo', 'estebanen', 'egipto', '30', 'mil', 'personas', 'entre', 'autoridades', 'gubernamentales', 'y', 'expertos', 'participarán', 'del', 'encuentrouna', 'nueva', 'edición', 'de', 'la', 'cumbre', 'climática', 'entre', 'el', 'escepticismo', 'y', 'la', 'esperanza', 'los', 'deba
# ...

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import csv 
  
file_ob = open(r"/content/drive/MyDrive/Colab Notebooks/scraping_notas_pagina12.csv") 
  
reader_ob = csv.reader(file_ob) 
  
reader_contents = list(reader_ob) 
  
text = "" 
  
for row in reader_contents : 
      
    
    for word in row : 
  
        
        text = text + " " + word 
  
wordcloud = WordCloud(width=480, height=480, max_words=19).generate(text) 
  
plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()

# %%
from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
import csv 
  
file_ob = open(r"/content/drive/MyDrive/Colab Notebooks/scraping_notas_pagina12.csv") 
  
reader_ob = csv.reader(file_ob) 
  
reader_contents = list(reader_ob) 
  
text = "" 
  
for row in reader_contents : 
      
    
    for word in row : 
  
        
        text = text + " " + word 
  
wordcloud = WordCloud(width=680, height=540, 
            stopwords=["todo","desde","sus","al","año","es","le","como","pero","las","se","su","e","los","el","a","la","lo","de","y","que","una","más","por","con","fue","cómo","en","del","un","no","para"]).generate(text) 
  
plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()

# %%
def limpiar_tokenizar(texto):
   #Esta función limpia y tokeniza el texto en palabras individuales.
   # El orden en el que se va limpiando el texto no es arbitrario.
    #El listado de signos de puntuación se ha obtenido de: print(string.punctuation)
  #  y re.escape(string.punctuation)
   
    
  # Se convierte todo el texto a minúsculas
     nuevo_texto = texto.lower()
    # Eliminación de páginas web (palabras que empiezan por "http")
     nuevo_texto = re.sub('http\S+', ' ', nuevo_texto)
    # Eliminación de signos de puntuación
     regex = '[\\!\\"\\#\\$\\%\\&\\\'\\(\\)\\*\\+\\,\\-\\.\\/\\:\\;\\<\\=\\>\\?\\@\\[\\\\\\]\\^_\\`\\{\\|\\}\\~]'
     nuevo_texto = re.sub(regex , ' ', nuevo_texto)
    # Eliminación de números
     nuevo_texto = re.sub("\d+", ' ', nuevo_texto)
    # Eliminación de espacios en blanco múltiples
     nuevo_texto = re.sub("\\s+", ' ', nuevo_texto)
    # Tokenización por palabras individuales
     nuevo_texto = nuevo_texto.split(sep = ' ')
    # Eliminación de tokens con una longitud < 2
     nuevo_texto = [token for token in nuevo_texto if len(token) > 1]
    
     return(nuevo_texto)

test = """En Egipto, 30 mil personas, entre autoridades gubernamentales y expertos, participarán del encuentroUna nueva edición de la cumbre climática, entre el escepticismo y la esperanza Los debates en torno al recambio de la matriz energética, el impacto de
la geopolítica en las posibilidades de cambio reales, los antecedentes y las proyecciones
oscuras, signadas por un financiamiento que se promete pero nunca llega para
las sociedades más vulnerables.   Por Pablo Esteban"""
print(test)
print(limpiar_tokenizar(texto=test))
# Out:
# En Egipto, 30 mil personas, entre autoridades gubernamentales y expertos, participarán del encuentroUna nueva edición de la cumbre climática, entre el escepticismo y la esperanza Los debates en torno al recambio de la matriz energética, el impacto de
# la geopolítica en las posibilidades de cambio reales, los antecedentes y las proyecciones
# oscuras, signadas por un financiamiento que se promete pero nunca llega para
# las sociedades más vulnerables.   Por Pablo Esteban
# ...

# %%
  import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/scraping_notas_pagina12.csv')
df[["titulo","cuerpo"]].head()
# Out:
#                                               titulo  \
# 0  En Egipto, 30 mil personas, entre autoridades ...
# 1  Durante su visita a Bahrein pidió cerrar la br...
# 2  A través de ‘James Webb’, el supertelescopio d...
# 3  Tres meses con el dólar planchado¿Aguanta la p...
# 4  El festival del Departamento de Folklore de la...
#
#                                               cuerpo
# 0  Este domingo empieza la cumbre mundial del cli...
# 1  El Papa consideró "infantil" el comportamiento...
# 2  A través del telescopio James Webb, la NASA co...
# 3  "Le ganamos a la incertidumbre y estabilizamos...
# 4  Se realizó la novena edición de FAPI “Folklore...

# %%
titulo =df.groupby("titulo")
titulo.describe().head()
# Out:
#                                                    Unnamed: 0                  \
#                                                         count  mean std   min
# titulo
# 2200 millones de dólares en dos proyectosNueva ...        1.0  45.0 NaN  45.0
# A través de ‘James Webb’, el supertelescopio de...        1.0   2.0 NaN   2.0
# Acabar con la internaPor Eduardo Aliverti                 1.0   7.0 NaN   7.0
# Afecta principalmente a niños, niñas y adolesce...        1.0  34.0 NaN  34.0
# Al menos cuatro palestinos muertos por fuerzas ...        1.0  51.0 NaN  51.0
#
#
#                                                      25%   50%   75%   max
# titulo
# 2200 millones de dólares en dos proyectosNueva ...  45.0  45.0  45.0  45.0
# A través de ‘James Webb’, el supertelescopio de...   2.0   2.0   2.0   2.0
# Acabar con la internaPor Eduardo Aliverti            7.0   7.0   7.0   7.0
# Afecta principalmente a niños, niñas y adolesce...  34.0  34.0  34.0  34.0
# ...

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import nltk

# %%
nltk.download()

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
text ='A través de ‘James Webb’, el supertelescopio de la NASACientíficos captaron las imágenes más nítidas de los anillos de NeptunoLa agencia espacial compartió una foto en la que se puede ver al planeta y a 7 de sus 14 lunas, incluída Tritón. El telescopio logró resaltar características de Neptuno que no se veían con tanto detalle desde que la sonda Voyager 2 sobrevoló el cuerpo celeste en 1989'

# %%
simple_tokens = text.split(" ")
print([token for token in simple_tokens])
# Out:
# ['A', 'través', 'de', '‘James', 'Webb’,', 'el', 'supertelescopio', 'de', 'la', 'NASACientíficos', 'captaron', 'las', 'imágenes', 'más', 'nítidas', 'de', 'los', 'anillos', 'de', 'NeptunoLa', 'agencia', 'espacial', 'compartió', 'una', 'foto', 'en', 'la', 'que', 'se', 'puede', 'ver', 'al', 'planeta', 'y', 'a', '7', 'de', 'sus', '14', 'lunas,', 'incluída', 'Tritón.', 'El', 'telescopio', 'logró', 'resaltar', 'características', 'de', 'Neptuno', 'que', 'no', 'se', 'veían', 'con', 'tanto', 'detalle', 'desde', 'que', 'la', 'sonda', 'Voyager', '2', 'sobrevoló', 'el', 'cuerpo', 'celeste', 'en', '1989']
